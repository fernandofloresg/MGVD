# %%
from boilerpipe.extract import Extractor
URL='http://www.uabc.mx'
extractor = Extractor(extractor='ArticleExtractor', url=URL)
print (extractor.getText())
# Out:
# Noticias
# Instituye UABC Día del Orgullo Cimarrón
# Campus Mexicali, 07 de octubre de 2017.- La Universidad Autónoma de Baja California (UABC) instituyó el Día del Orgullo Cimarrón, una celebración para unir a los universitarios y sociedad en general a través de momentos de esparcimiento en los que se celebra a la ciencia, el arte y la cultura.
# Noticias
# Entrega UABC más de 90 toneladas de acopio
# Campus Mexicali, 9 de octubre de 2017.- Más de 90 toneladas de acopio, conformado por medicamentos, alimentos no perecederos, artículos de higiene personal y de limpieza, ropa, entre otros productos, entregó la Universidad Autónoma de Baja California (UABC) a la Secretaría de Marina, por conducto del Gobierno del Estado de Baja California.

# %%
# System modules
from queue import Queue
from threading import Thread
from boilerpipe.extract import Extractor
import time, re

# Set up some global variables
num_threads = 10
page_number = 1 - num_threads
URLs_queue  = Queue()
initial_URL ='https://www.wikipedia.org/'

#Prevent the crawling of visitated urls
visitated_urls = []
obtained_links = 0
retained_links = 0
repeated_links = 0 
zero_links = 0
min_links = 0 
extraction_failed_links = 0

def getURLs(URL):
    extractor = Extractor(extractor='KeepEverythingExtractor', url=URL)
    pageContent = extractor.getHTML()
    URLs = re.findall('href=[\'"]?(.[^\'" >]+)', pageContent)
    return URLs

def populateQueue(URLs):
    global URLs_queue
    for entry in URLs:
        print(URLs_queue.qsize())
        print ('Queuing:', entry)
        URLs_queue.put(entry)


def ExtractPageContent(i, q):
    """By using an infinite loop, this function processes URLs in the queue, one after another.  
    Only exit when the main thread ends.
    """
    global page_number
    global obtained_links
    global retained_links
    global repeated_links
    global zero_links
    global min_links
    global extraction_failed_links
    char_number_tolerance = 100
    
    while True:
        print ('\n %s: Looking for the next URL' % i)
        url = q.get()
        
        if(url in visitated_urls):
            repeated_links += 1
        if (url.startswith("http")):
            obtained_links += 1
        if (url.startswith("http") and url not in visitated_urls) :
            try:
                retained_links = retained_links + 1
                print ('\n %s: Downloading:' % i, url)
                extractor = Extractor(extractor='ArticleExtractor', url=url)
                pageContent = extractor.getText()
                if (len(pageContent) == 0):
                    zero_links += 1
                else:
                    if(len(pageContent) < char_number_tolerance ):
                        min_links +=1
                        
                if (len(pageContent) > char_number_tolerance ): 
                    page_number +=1
                    file_name = "C:\MGVD\FC\webPage-" + str(page_number) + ".txt" 
                    print(file_name)
                    print (url)

                    f = open(file_name,"w+", encoding="utf-8")
                    f.write(pageContent)
                    f.close()

                    if (page_number < 5):
                        URLs = getURLs(url)
                        populateQueue(URLs)
                    visitated_urls.append(url)
            except:
                extraction_failed_links += 1 
                print("\n**** Extraction failed **** \n")
                
        q.task_done()


# Download the initial web-page and get its URLs
URLs = getURLs(initial_URL)
print('*********', len(URLs), '******** \n')


# Put the URLs into the queue.
URLs_queue.put(initial_URL)
populateQueue(URLs)
time.sleep(1)    
    
# Set up some threads to fetch web-pages data
for i in range(num_threads):
        worker = Thread(target=ExtractPageContent, args=(i, URLs_queue,))
        worker.setDaemon(True)
        worker.start()
time.sleep(1)

start_time = time.clock()

# Now wait for the queue to be empty, indicating that we have
# processed all of the downloads.
print ('*** Main thread waiting *** \n')
URLs_queue.join()
print ('*** Done *** \n')

# Elapsed time estimation
elapsed_time = time.clock() - start_time
print("Elapsed time: %0.10f seconds." % elapsed_time)
print('Obtained links: ', obtained_links)
print('Retained links: ', retained_links)
print('Repeated links: ', repeated_links)
print('Empty links: ', zero_links)
print('Under tolerance links: ', min_links)
