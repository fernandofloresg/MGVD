# %%
import json
import nltk
import numpy
from pprint import pprint  # For proper print of sequences.
import treetaggerwrapper


def entities(txt):
    sentences = [s for s in nltk.tokenize.sent_tokenize(txt)]
    #normalized_sentences = [s.lower() for s in sentences]
    
    previous_pos = None
    current_entity_chunk = []
    all_entity_chunks = []
    
    for s in sentences:
        tags = [treetaggerwrapper.make_tags(tagger.tag_text(s))]
        for tag in tags:
            for t in tag:
                token = t[0]
                pos   = t[1]
                if pos == previous_pos and pos.startswith('N'):
                    
                    current_entity_chunk.append(token)
                elif pos.startswith('N'):
                    if current_entity_chunk != []:
                        print(' '.join(current_entity_chunk))
                        all_entity_chunks.append((' '.join(current_entity_chunk), pos))
                        
                    current_entity_chunk = [token]
                previous_pos = pos
        
    return all_entity_chunks

txt = open("c:/MGVD/ensenada.txt", encoding="utf-8").read()
#txt = "Mr. Green killed Colonel Mustard in the study with the candlestick. Mr. Green is not a very nice fellow."

#1) build a TreeTagger wrapper:
tagger = treetaggerwrapper.TreeTagger(TAGLANG='es',TAGDIR='C:/Taggers/tree-tagger-windows-3.2/TreeTagger')

entities = entities(txt)
# Store the tokens as an index for the document and account for frequency.
frec = dict()
for c in entities:
    if c[0] in frec:
        frec[c[0]] += 1
    else:
        frec[c[0]] = 1    

print ('Entities Frequency')
print ('-------------')
print(frec)
print ()
# Out:
# ('Septiembre', 'NC')
# ('bahía', 'NP')
# ('Todos Santos', 'NC')
# ('navíos', 'NP')
# ('San Salvador', 'NP')
# ('Victoria', 'NC')
# ('mando', 'NP')
# ('Juan Rodríguez Cabrillo', 'NC')
# ('españoles', 'NC')
# ('mando', 'NC')
# ('ceremonia', 'NC')
# ('posesión', 'NC')
# ('nombre', 'NP')
# ('San Mateo', 'NC')
# ('nombre', 'NC')
# ('biógrafos', 'NP')
# ('Jesús', 'NC')
# ('Septiembre', 'NC')
# ('navegantes', 'NC')
# ('días', 'NC')
# ('entidad', 'NC')
# ('travesía', 'NC')
# ('norte', 'NC')
# ('españoles', 'NC')
# ('estancia', 'NC')
# ('viaje', 'NC')
# ('archivo', 'NC')
# ('indias', 'NP')
# ('Sevilla', 'NC')
# ('historiador', 'NC')
# ('Mathes', 'NC')
# ('expedición', 'NP')
# ('Juan Rodríguez Cabrillo', 'NC')
# ('costa', 'NC')
# ('toma', 'NC')
# ('posesión', 'NC')
# ('corona española', 'NC')
# ('no-existencia', 'NP')
# ('Tenochtitlanes', 'NP')
# ('Rodríguez Cabrillo', 'NC')
# ('distinción', 'NC')
# ('primero', 'NP')
# ('Océano', 'NC')
# ('litorales', 'NP')
# ('Baja', 'NP')
# ('Alta California', 'NC')
# ('años', 'NC')
# ('aparición', 'NC')
# ('litorales', 'NP')
# ('Sebastián Vizcaíno', 'NC')
# ('viaje', 'NC')
# ('exploración', 'NC')
# ('puertos', 'NC')
# ('refugio', 'NC')
# ('galeones', 'NP')
# ('Manila', 'NC')
# ('Noviembre', 'NC')
# ('bahía', 'NC')
# ('día', 'NP')
# ('Todos Santos', 'NC')
# ('nombre', 'NP')
# ('Ensenada', 'NP')
# ('Todos Santos', 'NC')
# ('región', 'NP')
# ('Ensenada', 'NC')
# ('siglos', 'NP')
# ('XVIII', 'NEG')
# ('no', 'NC')
# ('grupos', 'NC')
# ('etnias', 'NC')
# ('litorales', 'NC')
# ('misiones', 'NC')
# ('expansión', 'NC')
# ('norte', 'NC')
# ('antecedentes', 'NC')
# ('paraje', 'NP')
# ('La Ensenada', 'NP')
# ('Todos Santos', 'NC')
# ('Marzo', 'NP')
# ('Loretano Don José Manuel Ruíz', 'NC')
# ('alfarez', 'NC')
# ('Caballería', 'NC')
# ('Compañía', 'NP')
# ('Real', 'NC')
# ('Presidio', 'NP')
# ('Loreto', 'NC')
# ('comandante', 'NC')
# ('frontera', 'NP')
# ('Baja California', 'NC')
# ('gobernador', 'NP')
# ('Don José Joaquín', 'NP')
# ('Arrillaga', 'NC')
# ('concesión', 'NC')
# ('paraje', 'NP')
# ('Todos Santos', 'NP')
# ('Camino Real', 'NC')
# ('misiones', 'NP')
# ('Santo Tomas', 'NP')
# ('San Miguel', 'NC')
# ('gobernador', 'NC')
# ('antecedentes', 'NC')
# ('petición', 'NP')
# ('Ruíz', 'NC')
# ('información', 'NP')
# ('Julio', 'NC')
# ('predio', 'NP')
# ('Ensenada', 'NC')
# ('inteligencia', 'NC')
# ('sitio', 'NC')
# ('ganado', 'NC')
# ('reconocimiento', 'NC')
# ('dominio', 'NC')
# ('majestad', 'NC')
# ('peso', 'NC')
# ('ternero', 'NP')
# ('Julio', 'NC')
# ('sargento', 'NP')
# ('Estanislao Salgado', 'NC')
# ('posesión', 'NP')
# ('Don José Manuel Ruíz Carrillo', 'NC')
# ('paraje', 'NP')
# ('Ensenada', 'NP')
# ('Todos Santos', 'NC')
# ('señalamiento', 'NC')
# ('medición', 'NC')
# ('sitios', 'NC')
# ('ganado', 'NC')
# ('Maneadero', 'NC')
# ('Arroyo', 'NP')
# ('Carmen', 'NC')
# ('norte', 'NC')
# ('manera', 'NP')
# ('José Manuel Ruíz', 'NC')
# ('colono', 'NP')
# ('Ensenada', 'NC')
# ('honor', 'NC')
# ('calle', 'NP')
# ('Ciudad', 'NC')
# ('nombre', 'NC')
# ('hijas', 'NP')
# ('Ruíz', 'NC')
# ('nombre', 'NP')
# ('Salvadora Ruíz', 'NC')
# ('sargento', 'NP')
# ('Francisco Xavier Gastélum', 'NC')
# ('frontera', 'NC')
# ('Octubre', 'NC')
# ('comandante', 'NP')
# ('Ruíz', 'NP')
# ('Loreto', 'NC')
# ('puesto', 'NC')
# ('gobernador', 'NC')
# ('californias', 'NC')
# ('yerno', 'NC')
# ('sargento Gastélum', 'NC')
# ('predio', 'NP')
# ('Ensenada', 'NC')
# ('Gastélum', 'NC')
# ('propietario', 'NC')
# ('hijas', 'NP')
# ('Francisco Xavier Gastélum', 'NP')
# ('Salvadora', 'NP')
# ('María Luisa Gastélum Ruíz', 'NP')
# ('Pedro Gastélum Duarte', 'NC')
# ('apellido', 'NC')
# ('suegro', 'NEG')
# ('no', 'NC')
# ('familiares', 'NC')
# ('vez parientes', 'NP')
# ('Baja California Sur', 'NC')
# ('Don', 'NP')
# ('Francisco Xavier Gastélum', 'NP')
# ('Pedro Gastélum Duarte', 'NC')
# ('predio', 'NP')
# ('Ensenada', 'NC')
# ('Todos', 'NP')
# ('Santos', 'NC')
# ('pesos', 'NP')
# ('Mayo', 'NP')
# ('Pedro', 'NC')
# ('propietario', 'NP')
# ('Ensenada', 'NC')
# ('lugar', 'NC')
# ('casa', 'NP')
# ('Pedro', 'NC')
# ('lotes', 'NC')
# ('plano', 'NP')
# ('Señor Salvador', 'NC')
# ('Solorio', 'NC')
# ('actualidad', 'NC')
# ('playa', 'NP')
# ('Avenida Juárez', 'NC')
# ('calle', 'NP')
# ('Miramar', 'NP')
# ('Calle Ryerson', 'NC')
# ('hechos', 'NC')
# ('siglo', 'NP')
# ('XIX', 'NC')
# ('guerra', 'NP')
# ('México', 'NP')
# ('Estados Unidos', 'NC')
# ('guerra', 'NP')
# ('México', 'NC')
# ('motivos', 'NC')
# ('expansionismo', 'NC')
# ('fronteras', 'NC')
# ('este', 'NC')
# ('oeste', 'NC')
# ('Océano', 'NP')
# ('Atlántico', 'NP')
# ('Pacífico', 'NC')
# ('puertos', 'NP')
# ('San Francisco', 'NP')
# ('San Diego', 'NC')
# ('comercio', 'NC')
# ('hegemonía', 'NC')
# ('continente', 'NC')
# ('guerra', 'NP')
# ('México', 'NC')
# ('mitad', 'NC')
# ('territorio', 'NC')
# ('suceso', 'NC')
# ('región', 'NC')
# ('invasión', 'NP')
# ('William Walker', 'NC')
# ('Noviembre', 'NC')
# ('filibusteros', 'NC')
# ('casa', 'NP')
# ('Gastelúm', 'NC')
# ('cuartel', 'NC')
# ('nombre', 'NC')
# ('Fuerte', 'NP')
# ('Mckibbin', 'NC')
# ('honor', 'NC')
# ('filibusteros', 'NC')
# ('bahía', 'NC')
# ('invasores', 'NC')
# ('clase', 'NC')
# ('tropelías', 'NC')
# ('intenciones', 'NP')
# ('Walker', 'NP')
# ('República Independiente', 'NP')
# ('México', 'NC')
# ('nombre', 'NC')
# ('Sonora-Baja', 'NP')
# ('California', 'NP')
# ('Estados Unidos', 'NC')
# ('intenciones', 'NP')
# ('Antonio Meléndrez', 'NC')
# ('meses', 'NC')
# ('filibusteros', 'NC')
# ('línea', 'NP')
# ('Meléndrez', 'NC')
# ('rancheros', 'NC')
# ('Ensenada', 'NC')
# ('significado gracias', 'NC')
# ('descubrimiento', 'NC')
# ('minas', 'NP')
# ('Valle', 'NP')
# ('San Rafael', 'NC')
# ('grupo', 'NC')
# ('sonorenses', 'NC')
# ('vestigios', 'NC')
# ('oro', 'NC')
# ('este', 'NP')
# ('Ensenada', 'NC')
# ('mes', 'NP')
# ('Junio', 'NC')
# ('Ambrosio', 'NP')
# ('Castillo', 'NP')
# ('Hermosillo Sonora', 'NC')
# ('oro', 'NC')
# ('valle', 'NP')
# ('Rafael', 'NC')
# ('lugar', 'NC')
# ('honor', 'NP')
# ('Real', 'NP')
# ('Castillo', 'NC')
# ('población', 'NC')
# ('kilómetros', 'NC')
# ('este', 'NC')
# ('bahía', 'NP')
# ('Ensenada', 'NC')
# ('descubrimientos', 'NC')
# ('periódicos', 'NP')
# ('California', 'NC')
# ('región', 'NC')
# ('fiebre', 'NC')
# ('oro', 'NC')
# ('buscadores', 'NC')
# ('frontera', 'NC')
# ('bonanza', 'NC')
# ('pobladores', 'NC')
# ('puntos', 'NC')
# ('Baja', 'NP')
# ('California', 'NC')
# ('mineral', 'NC')
# ('mes', 'NC')
# ('Agosto', 'NC')
# ('valle', 'NP')
# ('San Rafael', 'NC')
# ('gambusinos', 'NC')
# ('metal', 'NC')
# ('Comerciantes', 'NC')
# ('puerto', 'NP')
# ('San Diego', 'NC')
# ('tiendas', 'NC')
# ('línea', 'NC')
# ('veces', 'NC')
# ('semana', 'NC')
# ('bahía', 'NP')
# ('San Diego', 'NC')
# ('minas', 'NC')
# ('gente', 'NC')
# ('fortuna', 'NC')
# ('pueblo', 'NC')
# ('habitantes', 'NC')
# ('capital', 'NP')
# ('Partido', 'NC')
# ('Norte', 'NP')
# ('Baja California', 'NC')
# ('tiempo', 'NP')
# ('Santo Tomás', 'NC')
# ('político', 'NP')
# ('Manuel Clemente Rojo', 'NC')
# ('desesperación', 'NC')
# ('lugar', 'NC')
# ('placeres', 'NC')
# ('fortuna', 'NEG')
# ('no', 'NC')
# ('margen', 'NC')
# ('archivos', 'NC')
# ('cabecera', 'NC')
# ('gobierno', 'NC')
# ('mineral', 'NEG')
# ('Ni', 'NC')
# ('jefatura', 'NP')
# ('Mayo', 'NC')
# ('año', 'NC')
# ('cambio', 'NC')
# ('cabecera', 'NC')
# ('autoridades', 'NP')
# ('La Paz', 'NC')
# ('gobernador', 'NP')
# ('José María Villagrana', 'NC')
# ('funciones', 'NC')
# ('Enero', 'NC')
# ('año', 'NC')
# ('cambio', 'NC')
# ('puerto', 'NP')
# ('Ensenada', 'NC')
# ('vía', 'NC')
# ('entrada', 'NC')
# ('mercancías', 'NC')
# ('provisiones', 'NP')
# ('San Diego', 'NP')
# ('San Francisco', 'NC')
# ('destino', 'NC')
# ('centros mineros', 'NC')
# ('años', 'NC')
# ('prosperidad', 'NC')
# ('minas', 'NC')
# ('importancia', 'NP')
# ('Real', 'NP')
# ('Castillo', 'NC')
# ('capital', 'NP')
# ('Partido', 'NC')
# ('años', 'NC')
# ('capital', 'NP')
# ('Mayo', 'NC')
# ('fecha', 'NC')
# ('fundación', 'NC')
# ('hecho', 'NC')
# ('venta', 'NC')
# ('solares', 'NC')
# ('parte', 'NP')
# ('Don Pedro Gastélum', 'NC')
# ('esfuerzo', 'NC')
# ('zonas', 'NP')
# ('País', 'NC')
# ('presidente', 'NP')
# ('República', 'NC')
# ('Diciembre', 'NC')
# ('ley', 'NC')
# ('colonización', 'NC')
# ('entrada', 'NC')
# ('capitales', 'NC')
# ('raíz', 'NC')
# ('decreto', 'NP')
# ('Luis Huller', 'NC')
# ('alemán', 'NC')
# ('concesión', 'NC')
# ('terrenos', 'NC')
# ('área', 'NC')
# ('superficie', 'NC')
# ('estado', 'NP')
# ('Baja California', 'NP')
# ('Huller', 'NP')
# ('George', 'NC')
# ('Sisson', 'NEG')
# ('no', 'NC')
# ('capital', 'NC')
# ('grupo', 'NC')
# ('inversionistas', 'NP')
# ('Marzo', 'NC')
# ('compañía', 'NP')
# ('México', 'NC')
# ('oficina', 'NP')
# ('Hartford', 'NP')
# ('Connecticut', 'NC')
# ('compañía', 'NEG')
# ('no', 'NC')
# ('sorpresa', 'NC')
# ('predio', 'NP')
# ('Ensenada', 'NP')
# ('Don Pedro Gastélum Duarte', 'NC')
# ('años', 'NC')
# ('solares', 'NC')
# ('Motivo', 'NC')
# ('compañía', 'NC')
# ('señor', 'NP')
# ('Maximiliano Beristein', 'NP')
# ('Don Pedro', 'NC')
# ('Gastélum', 'NC')
# ('tierras', 'NC')
# ('hectáreas', 'NP')
# ('Mayo', 'NC')
# ('cantidad', 'NC')
# ('pesos', 'NC')
# ('año', 'NC')
# ('Marzo', 'NP')
# ('Beristein', 'NC')
# ('terrenos', 'NP')
# ('Ensenada', 'NC')
# ('cantidad', 'NC')
# ('pesos', 'NC')
# ('compañía', 'NC')
# ('propiedades', 'NC')
# ('años', 'NP')
# ('Don Pedro', 'NP')
# ('Compañía Americana', 'NP')
# ('Ensenada', 'NC')
# ('signos', 'NC')
# ('progreso', 'NC')
# ('muelle', 'NC')
# ('comercios', 'NC')
# ('teléfonos', 'NC')
# ('telégrafos', 'NC')
# ('hoteles', 'NC')
# ('líneas', 'NC')
# ('vapores', 'NP')
# ('Ensenada', 'NP')
# ('San Diego', 'NC')
# ('regularidad', 'NC')
# ('objetivo', 'NP')
# ('Ensenada', 'NC')
# ('Ciudad', 'NC')
# ('terrenos', 'NC')
# ('precios', 'NC')
# ('decreto', 'NC')
# ('Congreso', 'NP')
# ('Unión', 'NC')
# ('Diciembre', 'NC')
# ('administración', 'NC')
# ('península', 'NC')
# ('distritos', 'NC')
# ('Distrito', 'NP')
# ('Norte', 'NC')
# ('capital', 'NP')
# ('Ensenada', 'NC')
# ('Distrito', 'NP')
# ('Sur', 'NC')
# ('capital', 'NP')
# ('La Paz', 'NC')
# ('embargo', 'NC')
# ('duración', 'NC')
# ('compañía', 'NC')
# ('manejos', 'NC')
# ('deudas', 'NC')
# ('desorganización', 'NC')
# ('aspectos', 'NC')
# ('gobierno', 'NP')
# ('Porfirio Díaz', 'NC')
# ('expertos', 'NC')
# ('presión', 'NEG')
# ('no', 'NP')
# ('Ensenada', 'NC')
# ('oficinas', 'NC')
# ('situación', 'NC')
# ('compañía', 'NC')
# ('territorios', 'NC')
# ('negocios', 'NC')
# ('derechos', 'NC')
# ('compañía', 'NC')
# ('terrenos', 'NC')
# ('colonización', 'NP')
# ('Compañía Inglesa', 'NP')
# ('Mayo', 'NC')
# ('compañías', 'NC')
# ('americana', 'NC')
# ('inglesa', 'NC')
# ('Ciudad', 'NP')
# ('Londres Inglaterra', 'NC')
# ('escritura', 'NC')
# ('bienes', 'NC')
# ('intereses', 'NC')
# ('créditos', 'NP')
# ('Baja California', 'NC')
# ('aprobación', 'NP')
# ('Secretaría', 'NC')
# ('Fomento', 'NP')
# ('México', 'NC')
# ('Septiembre', 'NC')
# ('campaña', 'NC')
# ('concesión', 'NP')
# ('Abril', 'NC')
# ('gobierno', 'NP')
# ('Venustiano Carranza', 'NC')
# ('compañía', 'NEG')
# ('no', 'NC')
# ('convenios', 'NC')
# ('gobierno', 'NP')
# Entities Frequency
# -------------
# {'Septiembre': 3, 'bahía': 5, 'Todos Santos': 6, 'navíos': 1, 'San Salvador': 1, 'Victoria': 1, 'mando': 2, 'Juan Rodríguez Cabrillo': 2, 'españoles': 2, 'ceremonia': 1, 'posesión': 3, 'nombre': 7, 'San Mateo': 1, 'biógrafos': 1, 'Jesús': 1, 'navegantes': 1, 'días': 1, 'entidad': 1, 'travesía': 1, 'norte': 3, 'estancia': 1, 'viaje': 2, 'archivo': 1, 'indias': 1, 'Sevilla': 1, 'historiador': 1, 'Mathes': 1, 'expedición': 1, 'costa': 1, 'toma': 1, 'corona española': 1, 'no-existencia': 1, 'Tenochtitlanes': 1, 'Rodríguez Cabrillo': 1, 'distinción': 1, 'primero': 1, 'Océano': 2, 'litorales': 3, 'Baja': 2, 'Alta California': 1, 'años': 5, 'aparición': 1, 'Sebastián Vizcaíno': 1, 'exploración': 1, 'puertos': 2, 'refugio': 1, 'galeones': 1, 'Manila': 1, 'Noviembre': 2, 'día': 1, 'Ensenada': 19, 'región': 3, 'siglos': 1, 'XVIII': 1, 'no': 7, 'grupos': 1, 'etnias': 1, 'misiones': 2, 'expansión': 1, 'antecedentes': 2, 'paraje': 3, 'La Ensenada': 1, 'Marzo': 3, 'Loretano Don José Manuel Ruíz': 1, 'alfarez': 1, 'Caballería': 1, 'Compañía': 1, 'Real': 3, 'Presidio': 1, 'Loreto': 2, 'comandante': 2, 'frontera': 3, 'Baja California': 4, 'gobernador': 4, 'Don José Joaquín': 1, 'Arrillaga': 1, 'concesión': 3, 'Camino Real': 1, 'Santo Tomas': 1, 'San Miguel': 1, 'petición': 1, 'Ruíz': 3, 'información': 1, 'Julio': 2, 'predio': 4, 'inteligencia': 1, 'sitio': 1, 'ganado': 2, 'reconocimiento': 1, 'dominio': 1, 'majestad': 1, 'peso': 1, 'ternero': 1, 'sargento': 2, 'Estanislao Salgado': 1, 'Don José Manuel Ruíz Carrillo': 1, 'señalamiento': 1, 'medición': 1, 'sitios': 1, 'Maneadero': 1, 'Arroyo': 1, 'Carmen': 1, 'manera': 1, 'José Manuel Ruíz': 1, 'colono': 1, 'honor': 3, 'calle': 2, 'Ciudad': 3, 'hijas': 2, 'Salvadora Ruíz': 1, 'Francisco Xavier Gastélum': 3, 'Octubre': 1, 'puesto': 1, 'californias': 1, 'yerno': 1, 'sargento Gastélum': 1, 'Gastélum': 2, 'propietario': 2, 'Salvadora': 1, 'María Luisa Gastélum Ruíz': 1, 'Pedro Gastélum Duarte': 2, 'apellido': 1, 'suegro': 1, 'familiares': 1, 'vez parientes': 1, 'Baja California Sur': 1, 'Don': 1, 'Todos': 1, 'Santos': 1, 'pesos': 3, 'Mayo': 5, 'Pedro': 2, 'lugar': 3, 'casa': 2, 'lotes': 1, 'plano': 1, 'Señor Salvador': 1, 'Solorio': 1, 'actualidad': 1, 'playa': 1, 'Avenida Juárez': 1, 'Miramar': 1, 'Calle Ryerson': 1, 'hechos': 1, 'siglo': 1, 'XIX': 1, 'guerra': 3, 'México': 6, 'Estados Unidos': 2, 'motivos': 1, 'expansionismo': 1, 'fronteras': 1, 'este': 3, 'oeste': 1, 'Atlántico': 1, 'Pacífico': 1, 'San Francisco': 2, 'San Diego': 5, 'comercio': 1, 'hegemonía': 1, 'continente': 1, 'mitad': 1, 'territorio': 1, 'suceso': 1, 'invasión': 1, 'William Walker': 1, 'filibusteros': 3, 'Gastelúm': 1, 'cuartel': 1, 'Fuerte': 1, 'Mckibbin': 1, 'invasores': 1, 'clase': 1, 'tropelías': 1, 'intenciones': 2, 'Walker': 1, 'República Independiente': 1, 'Sonora-Baja': 1, 'California': 3, 'Antonio Meléndrez': 1, 'meses': 1, 'línea': 2, 'Meléndrez': 1, 'rancheros': 1, 'significado gracias': 1, 'descubrimiento': 1, 'minas': 3, 'Valle': 1, 'San Rafael': 2, 'grupo': 2, 'sonorenses': 1, 'vestigios': 1, 'oro': 3, 'mes': 2, 'Junio': 1, 'Ambrosio': 1, 'Castillo': 3, 'Hermosillo Sonora': 1, 'valle': 2, 'Rafael': 1, 'población': 1, 'kilómetros': 1, 'descubrimientos': 1, 'periódicos': 1, 'fiebre': 1, 'buscadores': 1, 'bonanza': 1, 'pobladores': 1, 'puntos': 1, 'mineral': 2, 'Agosto': 1, 'gambusinos': 1, 'metal': 1, 'Comerciantes': 1, 'puerto': 2, 'tiendas': 1, 'veces': 1, 'semana': 1, 'gente': 1, 'fortuna': 2, 'pueblo': 1, 'habitantes': 1, 'capital': 6, 'Partido': 2, 'Norte': 2, 'tiempo': 1, 'Santo Tomás': 1, 'político': 1, 'Manuel Clemente Rojo': 1, 'desesperación': 1, 'placeres': 1, 'margen': 1, 'archivos': 1, 'cabecera': 2, 'gobierno': 4, 'Ni': 1, 'jefatura': 1, 'año': 3, 'cambio': 2, 'autoridades': 1, 'La Paz': 2, 'José María Villagrana': 1, 'funciones': 1, 'Enero': 1, 'vía': 1, 'entrada': 2, 'mercancías': 1, 'provisiones': 1, 'destino': 1, 'centros mineros': 1, 'prosperidad': 1, 'importancia': 1, 'fecha': 1, 'fundación': 1 ...
