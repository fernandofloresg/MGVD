# %%
from boilerpipe.extract import Extractor
URL='http://www.uabc.mx'
extractor = Extractor(extractor='ArticleExtractor', url=URL)
print (extractor.getText())
# Out:
# Noticias
# Inauguran la XII Jornada Bibliotecológica en Campus Ensenada
# Campus Ensenada, 27 de octubre de 2017.- La XII Jornada Bibliotecológica Arquitectura de bibliotecas: ética y responsabilidad social del bibliotecario, organizada por la Asociación de Bibliotecarios de Baja California A.C. (Abibac), en colaboración con la Universidad Autónoma de Baja California a través del Departamento de Información Académica del Campus Ensenada, fue inaugurada esta mańana ante la presencia de 120 participantes, entre ponentes, proveedores y bibliotecarios.
# Noticias
# Protege UABC propiedad intelectual de universitarios
# Campus Tijuana, 26 de octubre de 2017.- En sesión del Consejo Universitario de la Universidad Autónoma de Baja California (UABC), se aprobó el Reglamento de Propiedad Intelectual que contiene la normatividad para asistir al personal y alumnos en la preservación de sus derechos en la transferencia o adaptación de sus trabajos y resultados.

# %%
# System modules
from queue import Queue
from threading import Thread
from boilerpipe.extract import Extractor
import time, re

# Set up some global variables
num_threads = 8
page_number = 1 - num_threads
URLs_queue  = Queue()
initial_URL ='https://es.wikipedia.org/wiki/Filipinas'

#Prevent the crawling of visitated urls
visitated_urls = []
obtained_links = 0
retained_links = 0
repeated_links = 0 
zero_links = 0
min_links = 0 
extraction_failed_links = 0

def getURLs(URL):
    extractor = Extractor(extractor='KeepEverythingExtractor', url=URL)
    pageContent = extractor.getHTML()
    URLs = re.findall('href=[\'"]?(.[^\'" >]+)', pageContent)
    return URLs

def populateQueue(URLs):
    global URLs_queue
    print("URls : ", len(URLs))
    print("Queue size : ", URLs_queue.qsize())
    for entry in URLs:
        URLs_queue.put(entry)
    print("Queue size after inserting new URLs: " , URLs_queue.qsize())


def ExtractPageContent(i, q):
    """By using an infinite loop, this function processes URLs in the queue, one after another.  
    Only exit when the main thread ends.
    """
    global page_number
    global obtained_links
    global retained_links
    global repeated_links
    global zero_links
    global min_links
    global extraction_failed_links
    global URLs_queue
    char_number_tolerance = 100
    
    while True:
        url = q.get()
        
        if(url in visitated_urls):
            repeated_links += 1
        if (url.startswith("http")):
            obtained_links += 1
        if (url.startswith("http") and url not in visitated_urls) :
            try:
                retained_links = retained_links + 1
                extractor = Extractor(extractor='ArticleExtractor', url=url)
                pageContent = extractor.getText()
                if (len(pageContent) == 0):
                    zero_links += 1
                else:
                    if(len(pageContent) < char_number_tolerance ):
                        min_links +=1
                        
                if (len(pageContent) > char_number_tolerance ): 
                    page_number +=1
                    file_name = "C:\MGVD\FC\webPage-" + str(page_number) + ".txt" 

                    f = open(file_name,"w+", encoding="utf-8")
                    f.write(pageContent)
                    f.close()

                    if (page_number < 30):
                        URLs = getURLs(url)
                        if(not ((URLs_queue.qsize() + len(URLs))) >1000):
                            populateQueue(URLs)
                    visitated_urls.append(url)
            except:
                extraction_failed_links += 1 
                
        q.task_done()


# Download the initial web-page and get its URLs
URLs = getURLs(initial_URL)
print('*********', len(URLs), '******** \n')


# Put the URLs into the queue.
URLs_queue.put(initial_URL)
if len(URLs) > 2000 :
    populateQueue(URLs[:1800])
else:
    populateQueue(URLs)
time.sleep(1)

# Set up some threads to fetch web-pages data
for i in range(num_threads):
        worker = Thread(target=ExtractPageContent, args=(i, URLs_queue,))
        worker.setDaemon(True)
        worker.start()
time.sleep(1)

start_time = time.clock()

# Now wait for the queue to be empty, indicating that we have
# processed all of the downloads.
print ('*** Main thread waiting *** \n')
URLs_queue.join()
print ('*** Done *** \n')

# Elapsed time estimation
elapsed_time = time.clock() - start_time
print("Elapsed time: %0.10f seconds." % elapsed_time)
print('Obtained links: ', obtained_links)
print('Retained links: ', retained_links)
print('Repeated links: ', repeated_links)
print('Empty links: ', zero_links)
print('Under tolerance links: ', min_links)
# Out:
# ********* 2625 ********
#
# URls :  1800
# Queue size :  1
# Queue size after inserting new URLs:  1801
# *** Main thread waiting ***
#
# URls :  82
# Queue size :  265
# Queue size after inserting new URLs:  347
# URls :  54
# Queue size :  333
# Queue size after inserting new URLs:  387URls :
#  66
# Queue size :  384
# Queue size after inserting new URLs:  450
# URls :  14
# Queue size :  432
# Queue size after inserting new URLs:  446
# URls :  14
# Queue size :  440
# Queue size after inserting new URLs:  454
# URls :  101
# Queue size :  445
# Queue size after inserting new URLs:  546
# URls :  39
# Queue size :  519
# Queue size after inserting new URLs:  558
# URls :  135URls :  107
#
# Queue size : Queue size :   641540
#
# Queue size after inserting new URLs: Queue size after inserting new URLs:   776647
#
# URls :  102
# Queue size :  772
# Queue size after inserting new URLs:  874
# URls :  1
# Queue size :  871
# Queue size after inserting new URLs:  872
# URls :  12
# Queue size :  860
# Queue size after inserting new URLs:  872
# URls :  9
# Queue size :  854
# Queue size after inserting new URLs:  863
# URls :  3
# Queue size :  828
# Queue size after inserting new URLs:  831
# URls :  151
# Queue size :  828
# Queue size after inserting new URLs:  979
# URls :  13
# Queue size :  975
# Queue size after inserting new URLs:  988
# URls :  0
# Queue size :  986
# Queue size after inserting new URLs:  986
# URls :  15
# Queue size :  948
# Queue size after inserting new URLs:  963
# URls :  1
# Queue size :  962
# Queue size after inserting new URLs:  963
# URls :  9
# Queue size :  952
# Queue size after inserting new URLs:  961
# URls :  10
# Queue size :  933
# Queue size after inserting new URLs:  943
# URls :  46
# Queue size :  911
# Queue size after inserting new URLs:  957
# URls :  11
# Queue size :  953
# Queue size after inserting new URLs:  964
# URls :  11
# Queue size :  962
# Queue size after inserting new URLs:  973
# URls :  29
# Queue size :  966
# Queue size after inserting new URLs:  995
# URls :  33
# Queue size :  940
# Queue size after inserting new URLs:  973
# URls :  91
# Queue size :  845
# Queue size after inserting new URLs:  936
# *** Done ***
#
# Elapsed time: 191.7034194332 seconds.
# Obtained links:  592
# Retained links:  499
# Repeated links:  93
# Empty links:  33
# Under tolerance links:  33
